# %%
import pandas as pd
import numpy as np
import faker
import openpyxl
import json
import atoti as tt
import sqlalchemy

print("✅ pandas :", pd.__version__)
print("✅ numpy :", np.__version__)
print("✅ atoti : installé ✓")
print("✅ sqlalchemy :", sqlalchemy.__version__)
print("✅ Tout est prêt !")
# Out:
# ✅ pandas : 2.3.3
# ✅ numpy : 2.2.6
# ✅ atoti : installé ✓
# ✅ sqlalchemy : 2.0.47
# ✅ Tout est prêt !
